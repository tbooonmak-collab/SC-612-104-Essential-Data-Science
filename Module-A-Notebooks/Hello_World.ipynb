# %% [markdown]
# <a href="https://colab.research.google.com/github/PitchayaW/SC-612-104-Essential-Data-Science/blob/main/Module-A-Notebooks/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://i.imgur.com/ZAR4Uqc.png" alt="pandas" width="400"/>
# <p/>

# %% [markdown]
# Why do we learn Python programming?

# %% [markdown]
# * Python language is very simple and easy to handle
# * Python has an Abundance of Libraries and Frameworks
# * Python is used in Data Science, Web Development, Machine Learning, AI, etc.
# * Python is liable with large community
# * Python offers job opportunities
# * Python is available in various platform and FREE!

# %% [markdown]
# There are many Python IDLEs (Integrated Development and Learning Environment), some popular ones include

# %% [markdown]
# * A default editor: IDLE (Integrated Development and Learning Environment)
# * A default Python prompt through command line or scripts
# * Visual Studio Code
# * Jupyter Notebook
# * Spyder
# * PyCharm
# * Anaconda offered several applications including Jupyter Notebook and Spyder
# * Google Colaboratory

# %% [markdown]
# Google Colab
#
# * Quick Start of python learning without infra setup required
# * Available anywhere with internet connection
# * Easy to share
# * Support GPU and TPU for machine learning models
# * Google Drive is your source and target for Storage
# * Free to some limit with limited space (15GB) and time (12 hrs/day)

# %% [markdown]
# Let's try it out!

# %%
2+2
# Out:
# 4

# %%
print('Cool stuff!')
# Out:
# Cool stuff!

# %%
A = [1,2,3,4]

# %%
print(A)
# Out:
# [1, 2, 3, 4]

# %%
len(A)
# Out:
# 4

# %%
def f(x,y):
    return x+y

# %%
f(4,5)
# Out:
# 9

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# If you cannot import due to your computer cannot find, try installing the library using `pip install <library-name>`.
#
# Beginning the line with `!` direct your code to command line.

# %%
# !ls
# Out:
# sample_data

# %%
# !pip install numpy

# %% [markdown]
# # My Heading

# %% [markdown]
# * foo
# * bar
# * foobar

# %% [markdown]
# 1. foo
# 2. bar
# 3. foobar

# %% [markdown]
# # Header1

# %% [markdown]
# ## Header2

# %% [markdown]
# ![pythoncoding](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*Tl22PsXNMjWqvvDWhNdY6g.png)

# %% [markdown]
# | No. | Function | Description |
# | --- | :---: | ---: |
# | 1 | sum(x) | summation |
# | 2 | min(x) | minimum |
# | 3 | mean(x) | mean |

# %% [markdown]
# I love [KKU](https://www.kku.ac.th).

# %% [markdown]
# ## Another heading

# %% [markdown]
# Nice $\LaTeX$ typesetting
# $$
# \int_{-\infty}^{\infty} e^{2 \pi x} dx
# $$

# %% [markdown]
# Nice code typesetting
# ```python
# s = "Python syntax highlighting"
# print s
# ```

# %% [markdown]
# <center>Let's <em>roll!</em> Go! <b>Go!</b></center>

# %% [markdown]
# ### Some useful Markdown guides
# * https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
# * https://www.markdownguide.org/basic-syntax/ or https://www.markdownguide.org/cheat-sheet/
